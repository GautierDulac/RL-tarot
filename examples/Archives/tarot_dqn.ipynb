# %%
# %cd ..
# Out:
# /home/jovyan/personal_project/RL-tarot

# %%
"""
An example of learning a Deep-Q Agent on French Tarot Game
"""
import os
import time

import tensorflow as tf

import rlcard
from rlcard.agents.dqn_agent import DQNAgent
from rlcard.agents.random_agent import RandomAgent
from rlcard.utils.logger import Logger
from rlcard.utils.utils import set_global_seed, time_difference_good_format

# Make environment
env = rlcard.make('tarot')
eval_env = rlcard.make('tarot')

record_number = 20

# Set the iterations numbers and how frequently we evaluate/save plot
evaluate_every = 100
save_plot_every = 1000
evaluate_num = 5000
episode_num = 1000000


# Set the the number of steps for collecting normalization statistics
# and intial memory size
memory_init_size = 1000
norm_step = 1000

# The paths for saving the logs and learning curves
root_path = './experiments/tarot_dqn_result_v{}/'.format(str(record_number))
log_path = root_path + 'log.txt'
csv_path = root_path + 'performance.csv'
figure_path = root_path + 'figures/'

# Model save path
if not os.path.exists('rlcard/models'):
    os.makedirs('rlcard/models')
    if not os.path.exists('rlcard/models/pretrained'):
        os.makedirs('rlcard/models/pretrained')
        if not os.path.exists('rlcard/models/pretrained/tarot_v' + str(record_number)):
            os.makedirs('rlcard/models/pretrained/tarot_v' + str(record_number))
model_path = 'rlcard/models/pretrained/tarot_v' + str(record_number) + '/model'

# Set a global seed
#set_global_seed(0)

with tf.compat.v1.Session() as sess:
    # Set agents
    global_step = tf.Variable(0, name='global_step', trainable=False)
    agent = DQNAgent(sess,
                     scope='dqn',
                     action_num=78,  # env.action_num,
                     replay_memory_size=20000,
                     replay_memory_init_size=memory_init_size,
                     norm_step=norm_step,
                     state_shape=env.state_shape,
                     mlp_layers=[512, 512])

    random_agent = RandomAgent(action_num=eval_env.action_num)

    sess.run(tf.compat.v1.global_variables_initializer())

    saver = tf.compat.v1.train.Saver()

    env.set_agents([agent] + [random_agent] * (env.player_num - 1))
    eval_env.set_agents([agent] + [random_agent] * (env.player_num - 1))

    # Count the number of steps
    step_counter = 0

    total_game_played = 0
    seconds = time.time()

    # Init a Logger to plot the learning curve
    logger = Logger(xlabel='timestep', ylabel='reward', legend='DQN on TAROT',
                    legend_hist='Histogram of last evaluations', log_path=log_path, csv_path=csv_path)

    for episode in range(episode_num):
        print('\rEPISODE {} - Number of game played {} - {}'.format(episode, total_game_played,
                                                                    time_difference_good_format(seconds, time.time())),
              end='')

        # Generate data from the environment
        trajectories, _ = env.run(is_training=True)
        total_game_played += 1

        # Feed transitions into agent memory, and train the agent
        for ts in trajectories[0]:
            agent.feed(ts)
            step_counter += 1

            # Train the agent
            train_count = step_counter - (memory_init_size + norm_step)
            if train_count > 0:
                loss = agent.train()
                # print('\rINFO - Step {}, loss: {}'.format(step_counter, loss), end='')

        # Evaluate the performance. Play with random agents.
        if episode % evaluate_every == 0:
            # Save Model
            saver.save(sess, model_path)
            reward = 0
            reward_list = []
            for eval_episode in range(evaluate_num):
                print('\rEPISODE {} - Eval {} over {} - Number of game played {} - {}'.format(episode, eval_episode,
                                                                                              evaluate_num,
                                                                                              total_game_played,
                                                                                              time_difference_good_format(
                                                                                                  seconds,
                                                                                                  time.time())),
                      end='')
                _, payoffs = eval_env.run(is_training=False)
                total_game_played += 1
                reward_list.append(payoffs[0])
                reward += payoffs[0]

            logger.log('\n########## Evaluation - Episode {} ##########'.format(episode))
            logger.log('Timestep: {} Average reward is {}'.format(env.timestep, float(reward) / evaluate_num))

            # Add point to logger
            logger.add_point(x=env.timestep, y=float(reward) / evaluate_num)

        # Make plot
        if episode % save_plot_every == 0:
            logger.make_plot(save_path=figure_path + str(episode) + '.png')
            logger.make_plot_hist(save_path_1=figure_path + str(episode) + '_hist.png',
                                  save_path_2=figure_path + str(episode) + '_freq.png', reward_list=reward_list)

    # Make the final plot
    logger.make_plot(save_path=figure_path + 'final_' + str(episode) + '.png')
    logger.make_plot_hist(save_path_1=figure_path + str(episode) + '_hist.png',
                          save_path_2=figure_path + str(episode) + '_freq.png', reward_list=reward_list)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# EPISODE 0 - Eval 4999 over 5000 - Number of game played 5000 - 2 minutes and 48 seconds
# ########## Evaluation - Episode 0 ##########
# Timestep: 81 Average reward is -1.526
# EPISODE 100 - Eval 4999 over 5000 - Number of game played 10100 - 5 minutes and 43 seconds
# ########## Evaluation - Episode 100 ##########
# Timestep: 8117 Average reward is -0.6702
# EPISODE 200 - Eval 4999 over 5000 - Number of game played 15200 - 8 minutes and 47 seconds
# ########## Evaluation - Episode 200 ##########
# Timestep: 16147 Average reward is 0.198
# EPISODE 300 - Eval 4999 over 5000 - Number of game played 20300 - 11 minutes and 49 seconds
# ########## Evaluation - Episode 300 ##########
# Timestep: 24167 Average reward is -1.0684
# EPISODE 400 - Eval 4999 over 5000 - Number of game played 25400 - 14 minutes and 53 seconds
# ########## Evaluation - Episode 400 ##########
# Timestep: 32169 Average reward is -2.6414
# EPISODE 500 - Eval 4999 over 5000 - Number of game played 30500 - 17 minutes and 57 seconds
# ########## Evaluation - Episode 500 ##########
# Timestep: 40182 Average reward is -2.3266
# EPISODE 600 - Eval 4999 over 5000 - Number of game played 35600 - 21 minutes and 0 secondds
# ########## Evaluation - Episode 600 ##########
# Timestep: 48187 Average reward is -2.0402
# EPISODE 700 - Eval 4999 over 5000 - Number of game played 40700 - 24 minutes and 3 secondss
# ########## Evaluation - Episode 700 ##########
# Timestep: 56217 Average reward is -2.157
# EPISODE 800 - Eval 4999 over 5000 - Number of game played 45800 - 27 minutes and 9 secondss
# ########## Evaluation - Episode 800 ##########
# Timestep: 64242 Average reward is -3.4996
# EPISODE 900 - Eval 4999 over 5000 - Number of game played 50900 - 30 minutes and 12 seconds
# ########## Evaluation - Episode 900 ##########
# Timestep: 72285 Average reward is -1.2124
# EPISODE 1000 - Eval 4999 over 5000 - Number of game played 56000 - 33 minutes and 18 seconds
# ########## Evaluation - Episode 1000 ##########
# Timestep: 80292 Average reward is -3.9818
# EPISODE 1100 - Eval 4999 over 5000 - Number of game played 61100 - 36 minutes and 23 seconds
# ########## Evaluation - Episode 1100 ##########
# Timestep: 88326 Average reward is -2.2042
# EPISODE 1200 - Eval 4999 over 5000 - Number of game played 66200 - 39 minutes and 28 seconds
# ########## Evaluation - Episode 1200 ##########
# Timestep: 96351 Average reward is -2.6842
# EPISODE 1300 - Eval 4999 over 5000 - Number of game played 71300 - 42 minutes and 31 seconds
# ########## Evaluation - Episode 1300 ##########
# Timestep: 104380 Average reward is -2.3996
# EPISODE 1400 - Eval 4999 over 5000 - Number of game played 76400 - 45 minutes and 29 seconds
# ########## Evaluation - Episode 1400 ##########
# Timestep: 112399 Average reward is -1.9278
# EPISODE 1500 - Eval 4999 over 5000 - Number of game played 81500 - 48 minutes and 26 seconds
# ########## Evaluation - Episode 1500 ##########
# Timestep: 120421 Average reward is -0.8422
# EPISODE 1600 - Eval 4999 over 5000 - Number of game played 86600 - 51 minutes and 25 seconds
# ########## Evaluation - Episode 1600 ##########
# Timestep: 128441 Average reward is -2.4062
# EPISODE 1700 - Eval 4999 over 5000 - Number of game played 91700 - 54 minutes and 20 seconds
# ########## Evaluation - Episode 1700 ##########
# Timestep: 136473 Average reward is -0.485
# EPISODE 1800 - Eval 4999 over 5000 - Number of game played 96800 - 57 minutes and 18 seconds
# ########## Evaluation - Episode 1800 ##########
# Timestep: 144483 Average reward is -2.7076
# EPISODE 1900 - Eval 4999 over 5000 - Number of game played 101900 - 1 hour, 0 minute and 12 seconds
# ########## Evaluation - Episode 1900 ##########
# Timestep: 152515 Average reward is 0.5366
# EPISODE 2000 - Eval 4999 over 5000 - Number of game played 107000 - 1 hour, 3 minutes and 8 secondss
# ########## Evaluation - Episode 2000 ##########
# Timestep: 160522 Average reward is 0.5548
# EPISODE 2100 - Eval 4999 over 5000 - Number of game played 112100 - 1 hour, 6 minutes and 16 seconds
# ########## Evaluation - Episode 2100 ##########
# Timestep: 168545 Average reward is -4.3494
# EPISODE 2200 - Eval 4999 over 5000 - Number of game played 117200 - 1 hour, 9 minutes and 21 seconds
# ########## Evaluation - Episode 2200 ##########
# Timestep: 176572 Average reward is -2.9986
# EPISODE 2300 - Eval 4999 over 5000 - Number of game played 122300 - 1 hour, 12 minutes and 23 seconds
# ########## Evaluation - Episode 2300 ##########
# Timestep: 184578 Average reward is -1.7432
# EPISODE 2400 - Eval 4999 over 5000 - Number of game played 127400 - 1 hour, 15 minutes and 27 seconds
# ########## Evaluation - Episode 2400 ##########
# Timestep: 192577 Average reward is -3.06
# EPISODE 2500 - Eval 4999 over 5000 - Number of game played 132500 - 1 hour, 18 minutes and 26 seconds
# ########## Evaluation - Episode 2500 ##########
# Timestep: 200592 Average reward is -2.3414
# EPISODE 2600 - Eval 4999 over 5000 - Number of game played 137600 - 1 hour, 21 minutes and 24 seconds
# ########## Evaluation - Episode 2600 ##########
# Timestep: 208615 Average reward is -1.239
# EPISODE 2700 - Eval 4999 over 5000 - Number of game played 142700 - 1 hour, 24 minutes and 19 seconds
# ########## Evaluation - Episode 2700 ##########
# Timestep: 216628 Average reward is 0.697
# EPISODE 2800 - Eval 4999 over 5000 - Number of game played 147800 - 1 hour, 27 minutes and 14 seconds
# ########## Evaluation - Episode 2800 ##########
# Timestep: 224643 Average reward is 0.748
# EPISODE 2900 - Eval 4999 over 5000 - Number of game played 152900 - 1 hour, 30 minutes and 14 seconds
# ########## Evaluation - Episode 2900 ##########
# Timestep: 232666 Average reward is -2.585
# EPISODE 3000 - Eval 4999 over 5000 - Number of game played 158000 - 1 hour, 33 minutes and 25 seconds
# ########## Evaluation - Episode 3000 ##########
# Timestep: 240672 Average reward is -8.9346
# EPISODE 3100 - Eval 4999 over 5000 - Number of game played 163100 - 1 hour, 36 minutes and 31 seconds
# ########## Evaluation - Episode 3100 ##########
# Timestep: 248687 Average reward is -5.5678
# EPISODE 3200 - Eval 4999 over 5000 - Number of game played 168200 - 1 hour, 39 minutes and 31 seconds
# ########## Evaluation - Episode 3200 ##########
# Timestep: 256709 Average reward is -1.02
# EPISODE 3300 - Eval 4999 over 5000 - Number of game played 173300 - 1 hour, 42 minutes and 35 seconds
# ########## Evaluation - Episode 3300 ##########
# Timestep: 264712 Average reward is -2.0256
# EPISODE 3400 - Eval 4999 over 5000 - Number of game played 178400 - 1 hour, 45 minutes and 38 seconds
# ########## Evaluation - Episode 3400 ##########
# Timestep: 272718 Average reward is -1.3602
# EPISODE 3500 - Eval 4999 over 5000 - Number of game played 183500 - 1 hour, 48 minutes and 39 seconds
# ########## Evaluation - Episode 3500 ##########
# Timestep: 280729 Average reward is -0.8466
# EPISODE 3600 - Eval 4999 over 5000 - Number of game played 188600 - 1 hour, 51 minutes and 36 seconds
# ########## Evaluation - Episode 3600 ##########
# Timestep: 288728 Average reward is 0.2278
# EPISODE 3700 - Eval 4999 over 5000 - Number of game played 193700 - 1 hour, 54 minutes and 37 seconds
# ########## Evaluation - Episode 3700 ##########
# Timestep: 296717 Average reward is -2.2828
# EPISODE 3800 - Eval 4999 over 5000 - Number of game played 198800 - 1 hour, 57 minutes and 38 seconds
# ########## Evaluation - Episode 3800 ##########
# Timestep: 304723 Average reward is -1.3306
# EPISODE 3900 - Eval 4999 over 5000 - Number of game played 203900 - 2 hours, 0 minute and 36 secondss
# ########## Evaluation - Episode 3900 ##########
# Timestep: 312736 Average reward is -0.401
# EPISODE 3917 - Number of game played 203917 - 2 hours, 0 minute and 39 seconds

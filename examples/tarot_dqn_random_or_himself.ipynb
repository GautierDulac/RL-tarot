# %%
# %cd ..

# %%
import warnings
warnings.simplefilter('ignore')

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

import tensorflow as tf
tf.get_logger().setLevel('INFO')
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
warnings.filterwarnings('ignore')
"""
An example of learning a Deep-Q Agent on French Tarot Game
"""
import os
import time

import tensorflow as tf

import rlcard
from rlcard.agents.dqn_agent import DQNAgent
from rlcard.agents.random_agent import RandomAgent
from rlcard.utils.logger import Logger
from rlcard.utils.utils import time_difference_good_format

record_number = 27

# Make environment
env = rlcard.make('tarot')
eval_env = rlcard.make('tarot')

# Set the iterations numbers and how frequently we evaluate/save plot
evaluate_every = 500
evaluate_num = 1000
episode_num = 10000
# Train against
train_against = 'mixte_2'  # 'same' or 'random'

# Set the the number of steps for collecting normalization statistics
# and intial memory size
memory_init_size = 5000
norm_step = 1000

# The paths for saving the logs and learning curves
root_path = './experiments/{}_played_{}/'.format(train_against, str(record_number))
log_path_random = root_path + 'log_random.txt'
csv_path_random = root_path + 'performance_random.csv'
figure_path_random = root_path + 'figures_random/'

log_path_parameters = root_path + 'log_parameters.txt'



# Model save path
if not os.path.exists('rlcard/models'):
    os.makedirs('rlcard/models')
if not os.path.exists('rlcard/models/pretrained'):
    os.makedirs('rlcard/models/pretrained')
for eval_number in range(1, episode_num // evaluate_every + 1):
    model_folder_path = 'rlcard/models/pretrained/{}_played_{}/tarot_v{}'.format(train_against,
                                                                                 str(record_number),
                                                                                 str(
                                                                                     record_number * 10000 + eval_number))
    if not os.path.exists(model_folder_path):
        os.makedirs(model_folder_path)
model_path = 'rlcard/models/pretrained/{}_played_{}/tarot_v{}/model'.format(train_against,
                                                                            str(record_number),
                                                                            str(record_number * 10000))
# Init a Logger to plot the learning curve against random
logger_random = Logger(xlabel='episode', ylabel='reward', legend='DQN on TAROT against Random',
                       legend_hist='Histogram of last evaluations against Random', log_path=log_path_random,
                       csv_path=csv_path_random)

param_file = open(log_path_parameters, 'w')
param_file.write('record_number: {}'.format(record_number) + '\n')
param_file.write('evaluate_every: {}'.format(evaluate_every) + '\n')
param_file.write('evaluate_num: {}'.format(evaluate_num) + '\n')
param_file.write('episode_num: {}'.format(episode_num) + '\n')
param_file.write('train_against: {}'.format(train_against) + '\n')
param_file.write('memory_init_size: {}'.format(memory_init_size) + '\n')
param_file.write('norm_step: {}'.format(norm_step) + '\n')
param_file.flush()
param_file.close()

random_agent = RandomAgent(action_num=78)

with tf.compat.v1.Session() as sess:
    # Set agents
    global_step = tf.Variable(0, name='global_step', trainable=False)
    agent = DQNAgent(sess,
                     scope='dqn',
                     action_num=78,  # env.action_num,
                     replay_memory_size=20000,
                     replay_memory_init_size=memory_init_size,
                     norm_step=norm_step,
                     state_shape=env.state_shape,
                     mlp_layers=[512, 1024, 512])

    sess.run(tf.compat.v1.global_variables_initializer())

    saver = tf.compat.v1.train.Saver(max_to_keep=None)
    if train_against == 'random':
        env.set_agents([agent] + [random_agent] * (env.player_num - 1))
    elif train_against == 'mixte_2':
        env.set_agents([agent] + [agent] + [random_agent] * (env.player_num - 2))
    else:
        env.set_agents([agent] + [agent] * (env.player_num - 1))

    eval_env.set_agents([agent] + [random_agent] * (env.player_num - 1))

    # Count the number of steps
    step_counter = 0



    total_game_played = 0
    seconds = time.time()

    for episode in range(episode_num):
        # Evaluate the performance.
        if episode % evaluate_every == 0:
            # Save Model

            model_path = 'rlcard/models/pretrained/{}_played_{}/tarot_v{}/model'.format(train_against,
                                                                                        str(record_number),
                                                                                        str(
                                                                                            record_number * 10000 + episode // evaluate_every))

            saver.save(sess, model_path)

            # Eval against random
            reward_random = 0
            reward_random_list = []
            taking_list = []
            taking_reward = 0
            taking_reward_list = []
            for eval_episode in range(evaluate_num):
                print('\rEPISODE {} - Eval Random {} over {} - Number of game played {} - {}'.format(episode,
                                                                                                     eval_episode,
                                                                                                     evaluate_num,
                                                                                                     total_game_played,
                                                                                                     time_difference_good_format(
                                                                                                         seconds,
                                                                                                         time.time())),
                      end='')
                _, payoffs = eval_env.run(is_training=False)
                total_game_played += 1
                reward_random_list.append(payoffs[0])
                reward_random += payoffs[0]
                taking_list.append(eval_env.game.players[0].taking)
                if taking_list[-1]:
                    taking_reward_list.append(payoffs[0])
                    taking_reward += payoffs[0]

            logger_random.log('\n########## Evaluation Against Random - Episode {} ##########'.format(episode))
            logger_random.log(
                'Timestep: {} Average reward against random is {:.2f}'.format(env.timestep,
                                                                          float(reward_random) / evaluate_num))
            if taking_reward_list != []:
                logger_random.log('Timestep: {} Average reward when taking  is {:.2f}'.format(env.timestep,
                                                                          float(taking_reward) / len(taking_reward_list)))

            # Add point to logger
            logger_random.add_point(x=episode, y=float(reward_random) / evaluate_num)

            # Make plot
            logger_random.make_plot(save_path=figure_path_random + str(episode) + '.png')
            logger_random.make_plot_hist(save_path_1=figure_path_random + str(episode) + '_hist.png',
                                         save_path_2=figure_path_random + str(episode) + '_freq.png',
                                         reward_list=reward_random_list, taking_list=taking_list)

        print('\rEPISODE {} - Number of game played {} - {}'.format(episode, total_game_played,
                                                                    time_difference_good_format(seconds,
                                                                                                time.time())),
              end='')

        # Generate data from the environment
        trajectories, _ = env.run(is_training=True)
        total_game_played += 1

        # Feed transitions into agent memory, and train the agent
        for ts in trajectories[0]:
            agent.feed(ts)
            step_counter += 1

            # Train the agent
            train_count = step_counter - (memory_init_size + norm_step)
            if train_count > 0:
                loss = agent.train()
                # print('\rINFO - Step {}, loss: {}'.format(step_counter, loss), end='')

    # Make the final plot
    logger_random.make_plot(save_path=figure_path_random + 'final_' + str(episode) + '.png')
    logger_random.make_plot_hist(save_path_1=figure_path_random + str(episode) + '_hist.png',
                                 save_path_2=figure_path_random + str(episode) + '_freq.png',
                                 reward_list=reward_random_list, taking_list=taking_list)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# EPISODE 0 - Eval Random 999 over 1000 - Number of game played 999 - 34 seconds
# ########## Evaluation Against Random - Episode 0 ##########
# Timestep: 0 Average reward against random is 1.13
# Timestep: 0 Average reward when taking  is -7.44
# EPISODE 500 - Eval Random 999 over 1000 - Number of game played 2499 - 2 minutes and 30 seconds
# ########## Evaluation Against Random - Episode 500 ##########
# Timestep: 40025 Average reward against random is 2.48
# EPISODE 1000 - Eval Random 999 over 1000 - Number of game played 3999 - 5 minutes and 30 seconds
# ########## Evaluation Against Random - Episode 1000 ##########
# Timestep: 79972 Average reward against random is 2.30
# EPISODE 1500 - Eval Random 999 over 1000 - Number of game played 5499 - 8 minutes and 41 seconds
# ########## Evaluation Against Random - Episode 1500 ##########
# Timestep: 119956 Average reward against random is 2.30
# Timestep: 119956 Average reward when taking  is -6.00
# EPISODE 2000 - Eval Random 999 over 1000 - Number of game played 6999 - 11 minutes and 46 seconds
# ########## Evaluation Against Random - Episode 2000 ##########
# Timestep: 159961 Average reward against random is 2.32
# EPISODE 2500 - Eval Random 999 over 1000 - Number of game played 8499 - 14 minutes and 57 seconds
# ########## Evaluation Against Random - Episode 2500 ##########
# Timestep: 199990 Average reward against random is 2.46
# Timestep: 199990 Average reward when taking  is 5.00
# EPISODE 3000 - Eval Random 999 over 1000 - Number of game played 9999 - 18 minutes and 1 secondds
# ########## Evaluation Against Random - Episode 3000 ##########
# Timestep: 239979 Average reward against random is 2.34
# EPISODE 3500 - Eval Random 999 over 1000 - Number of game played 11499 - 21 minutes and 6 secondss
# ########## Evaluation Against Random - Episode 3500 ##########
# Timestep: 279944 Average reward against random is 2.37
# EPISODE 4000 - Eval Random 999 over 1000 - Number of game played 12999 - 24 minutes and 5 secondss
# ########## Evaluation Against Random - Episode 4000 ##########
# Timestep: 319961 Average reward against random is 2.33
# EPISODE 4500 - Eval Random 999 over 1000 - Number of game played 14499 - 27 minutes and 3 secondss
# ########## Evaluation Against Random - Episode 4500 ##########
# Timestep: 359991 Average reward against random is 2.33
# EPISODE 5000 - Eval Random 999 over 1000 - Number of game played 15999 - 30 minutes and 4 secondss
# ########## Evaluation Against Random - Episode 5000 ##########
# Timestep: 400060 Average reward against random is 2.38
# Timestep: 400060 Average reward when taking  is 3.00
# EPISODE 5500 - Eval Random 999 over 1000 - Number of game played 17499 - 32 minutes and 59 seconds
# ########## Evaluation Against Random - Episode 5500 ##########
# Timestep: 440049 Average reward against random is 2.53
# EPISODE 6000 - Eval Random 999 over 1000 - Number of game played 18999 - 35 minutes and 54 seconds
# ########## Evaluation Against Random - Episode 6000 ##########
# Timestep: 480051 Average reward against random is 2.41
# Timestep: 480051 Average reward when taking  is 3.00
# EPISODE 6500 - Eval Random 999 over 1000 - Number of game played 20499 - 38 minutes and 51 seconds
# ########## Evaluation Against Random - Episode 6500 ##########
# Timestep: 520062 Average reward against random is 2.19
# Timestep: 520062 Average reward when taking  is 2.00
# EPISODE 7000 - Eval Random 999 over 1000 - Number of game played 21999 - 41 minutes and 51 seconds
# ########## Evaluation Against Random - Episode 7000 ##########
# Timestep: 560127 Average reward against random is 2.31
# EPISODE 7500 - Eval Random 999 over 1000 - Number of game played 23499 - 44 minutes and 53 seconds
# ########## Evaluation Against Random - Episode 7500 ##########
# Timestep: 600110 Average reward against random is 2.27
# Timestep: 600110 Average reward when taking  is 3.00
# EPISODE 8000 - Eval Random 999 over 1000 - Number of game played 24999 - 47 minutes and 53 seconds
# ########## Evaluation Against Random - Episode 8000 ##########
# Timestep: 640079 Average reward against random is 2.31
# Timestep: 640079 Average reward when taking  is 4.00
# EPISODE 8500 - Eval Random 999 over 1000 - Number of game played 26499 - 50 minutes and 57 seconds
# ########## Evaluation Against Random - Episode 8500 ##########
# Timestep: 680081 Average reward against random is -2.25
# Timestep: 680081 Average reward when taking  is -6.75
# EPISODE 9000 - Eval Random 999 over 1000 - Number of game played 27999 - 53 minutes and 54 seconds
# ########## Evaluation Against Random - Episode 9000 ##########
# Timestep: 720044 Average reward against random is 2.24
# Timestep: 720044 Average reward when taking  is -6.00
# EPISODE 9500 - Eval Random 999 over 1000 - Number of game played 29499 - 56 minutes and 54 seconds
# ########## Evaluation Against Random - Episode 9500 ##########
# Timestep: 760043 Average reward against random is 2.23
# Timestep: 760043 Average reward when taking  is -9.00
# EPISODE 9999 - Number of game played 29999 - 59 minutes and 17 seconds

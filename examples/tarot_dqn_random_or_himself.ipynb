# %%
# %cd ..
# Out:
# /home/jovyan/personal_project/RL-tarot

# %%
"""
An example of learning a Deep-Q Agent on French Tarot Game
"""
import os
import time

import tensorflow as tf

import rlcard
from rlcard.agents.dqn_agent import DQNAgent
from rlcard.agents.random_agent import RandomAgent
from rlcard.utils.logger import Logger
from rlcard.utils.utils import time_difference_good_format

record_number = 15

# Make environment
env = rlcard.make('tarot')
eval_env = rlcard.make('tarot')

# Set the iterations numbers and how frequently we evaluate/save plot
evaluate_every = 100
evaluate_num = 1000
episode_num = 100000
# Train against
train_againt = 'random'  # or 'same'

# Set the the number of steps for collecting normalization statistics
# and intial memory size
memory_init_size = 5000
norm_step = 1000

# The paths for saving the logs and learning curves
root_path = './experiments/tarot_dqn_self_played_v{}/'.format(str(record_number))
log_path_random = root_path + 'log_random.txt'
csv_path_random = root_path + 'performance_random.csv'
figure_path_random = root_path + 'figures_random/'

# Model save path
if not os.path.exists('rlcard/models'):
    os.makedirs('rlcard/models')
if not os.path.exists('rlcard/models/pretrained'):
    os.makedirs('rlcard/models/pretrained')
for eval_number in range(1, episode_num // evaluate_every + 1):
    model_folder_path = 'rlcard/models/pretrained/{}_played_{}/tarot_v{}'.format(train_againt,
                                                                                 str(record_number),
                                                                                 str(
                                                                                     record_number * 10000 + eval_number))
    if not os.path.exists(model_folder_path):
        os.makedirs(model_folder_path)
model_path = 'rlcard/models/pretrained/{}_played_{}/tarot_v{}/model'.format(train_againt,
                                                                            str(record_number),
                                                                            str(record_number * 10000))

random_agent = RandomAgent(action_num=78)

with tf.compat.v1.Session() as sess:
    # Set agents
    global_step = tf.Variable(0, name='global_step', trainable=False)
    agent = DQNAgent(sess,
                     scope='dqn',
                     action_num=78,  # env.action_num,
                     replay_memory_size=20000,
                     replay_memory_init_size=memory_init_size,
                     norm_step=norm_step,
                     state_shape=env.state_shape,
                     mlp_layers=[512, 1024, 512])

    sess.run(tf.compat.v1.global_variables_initializer())

    saver = tf.compat.v1.train.Saver(max_to_keep=None)
    if train_againt == 'random':
        env.set_agents([agent] + [random_agent] * (env.player_num - 1))
    else:
        env.set_agents([agent] + [agent] * (env.player_num - 1))

    eval_env.set_agents([agent] + [random_agent] * (env.player_num - 1))

    # Count the number of steps
    step_counter = 0

    # Init a Logger to plot the learning curve against random
    logger_random = Logger(xlabel='episode', ylabel='reward', legend='DQN on TAROT against Random',
                           legend_hist='Histogram of last evaluations against Random', log_path=log_path_random,
                           csv_path=csv_path_random)

    total_game_played = 0
    seconds = time.time()

    for episode in range(episode_num):
        # Evaluate the performance.
        if episode % evaluate_every == 0:
            # Save Model

            model_path = 'rlcard/models/pretrained/{}_played_{}/tarot_v{}/model'.format(train_againt,
                                                                                        str(record_number),
                                                                                        str(
                                                                                            record_number * 10000 + episode // evaluate_every))

            saver.save(sess, model_path)

            # Eval against random
            reward_random = 0
            reward_random_list = []
            taking_list = []
            for eval_episode in range(evaluate_num):
                print('\rEPISODE {} - Eval Random {} over {} - Number of game played {} - {}'.format(episode,
                                                                                                     eval_episode,
                                                                                                     evaluate_num,
                                                                                                     total_game_played,
                                                                                                     time_difference_good_format(
                                                                                                         seconds,
                                                                                                         time.time())),
                      end='')
                _, payoffs = eval_env.run(is_training=False)
                total_game_played += 1
                reward_random_list.append(payoffs[0])
                reward_random += payoffs[0]
                taking_list.append(eval_env.game.players[0].taking)

            logger_random.log('\n########## Evaluation Against Random - Episode {} ##########'.format(episode))
            logger_random.log(
                'Timestep: {} Average reward against random is {}'.format(env.timestep,
                                                                          float(reward_random) / evaluate_num))

            # Add point to logger
            logger_random.add_point(x=episode, y=float(reward_random) / evaluate_num)

            # Make plot
            logger_random.make_plot(save_path=figure_path_random + str(episode) + '.png')
            logger_random.make_plot_hist(save_path_1=figure_path_random + str(episode) + '_hist.png',
                                         save_path_2=figure_path_random + str(episode) + '_freq.png',
                                         reward_list=reward_random_list, taking_list=taking_list)

        print('\rEPISODE {} - Number of game played {} - {}'.format(episode, total_game_played,
                                                                    time_difference_good_format(seconds,
                                                                                                time.time())),
              end='')

        # Generate data from the environment
        trajectories, _ = env.run(is_training=True)
        total_game_played += 1

        # Feed transitions into agent memory, and train the agent
        for ts in trajectories[0]:
            agent.feed(ts)
            step_counter += 1

            # Train the agent
            train_count = step_counter - (memory_init_size + norm_step)
            if train_count > 0:
                loss = agent.train()
                # print('\rINFO - Step {}, loss: {}'.format(step_counter, loss), end='')

    # Make the final plot
    logger_random.make_plot(save_path=figure_path_random + 'final_' + str(episode) + '.png')
    logger_random.make_plot_hist(save_path_1=figure_path_random + str(episode) + '_hist.png',
                                 save_path_2=figure_path_random + str(episode) + '_freq.png',
                                 reward_list=reward_random_list, taking_list=taking_list)
# Out:
# tarot-rule-v1
# rlcard.models.tarot_rule_models:TAROTRuleModelV1
# tarot-bid-rule-v1
# rlcard.models.tarot_bid_rule_models:TAROTBIDRuleModelV1
# tarot-dog-rule-v1
# rlcard.models.tarot_dog_rule_models:TAROTDOGRuleModelV1
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /home/jovyan/personal_project/RL-tarot/rlcard/models/pretrained/tarot_v10/model
# EPISODE 0 - Eval 999 over 1000 - Number of game played 1000 - 1 minute and 16 seconds
# ########## Evaluation - Episode 0 ##########
# Timestep: 81 Average reward is 0.139
# EPISODE 1000 - Eval 999 over 1000 - Number of game played 3000 - 5 minutes and 14 seconds
# ########## Evaluation - Episode 1000 ##########
# Timestep: 80360 Average reward is -1.988
# EPISODE 2000 - Eval 999 over 1000 - Number of game played 5000 - 9 minutes and 51 seconds
# ########## Evaluation - Episode 2000 ##########
# Timestep: 160681 Average reward is -0.037
# EPISODE 3000 - Eval 999 over 1000 - Number of game played 7000 - 14 minutes and 32 seconds
# ########## Evaluation - Episode 3000 ##########
# Timestep: 241054 Average reward is 0.18
# EPISODE 4000 - Eval 999 over 1000 - Number of game played 9000 - 19 minutes and 14 seconds
# ########## Evaluation - Episode 4000 ##########
# Timestep: 321305 Average reward is -1.283
# EPISODE 5000 - Eval 999 over 1000 - Number of game played 11000 - 23 minutes and 54 seconds
# ########## Evaluation - Episode 5000 ##########
# Timestep: 401481 Average reward is -3.819
# EPISODE 6000 - Eval 999 over 1000 - Number of game played 13000 - 28 minutes and 27 seconds
# ########## Evaluation - Episode 6000 ##########
# Timestep: 481351 Average reward is -3.716
# EPISODE 7000 - Eval 999 over 1000 - Number of game played 15000 - 33 minutes and 2 secondss
# ########## Evaluation - Episode 7000 ##########
# Timestep: 561186 Average reward is -5.039
# EPISODE 8000 - Eval 999 over 1000 - Number of game played 17000 - 37 minutes and 37 seconds
# ########## Evaluation - Episode 8000 ##########
# Timestep: 640993 Average reward is -2.512
# EPISODE 9000 - Eval 999 over 1000 - Number of game played 19000 - 42 minutes and 9 secondss
# ########## Evaluation - Episode 9000 ##########
# Timestep: 720827 Average reward is -0.97
# EPISODE 10000 - Eval 999 over 1000 - Number of game played 21000 - 46 minutes and 37 seconds
# ########## Evaluation - Episode 10000 ##########
# Timestep: 800641 Average reward is -4.471
# EPISODE 11000 - Eval 999 over 1000 - Number of game played 23000 - 51 minutes and 4 secondss
# ########## Evaluation - Episode 11000 ##########
# Timestep: 880599 Average reward is -0.597
# EPISODE 12000 - Eval 999 over 1000 - Number of game played 25000 - 55 minutes and 31 seconds
# ########## Evaluation - Episode 12000 ##########
# Timestep: 960756 Average reward is 0.228
# EPISODE 13000 - Eval 999 over 1000 - Number of game played 27000 - 1 hour, 0 minute and 1 second
# ########## Evaluation - Episode 13000 ##########
# Timestep: 1041038 Average reward is 1.457
# EPISODE 14000 - Eval 999 over 1000 - Number of game played 29000 - 1 hour, 4 minutes and 30 seconds
# ########## Evaluation - Episode 14000 ##########
# Timestep: 1121245 Average reward is -0.871
# EPISODE 15000 - Eval 999 over 1000 - Number of game played 31000 - 1 hour, 8 minutes and 58 seconds
# ########## Evaluation - Episode 15000 ##########
# Timestep: 1201441 Average reward is 2.311
# EPISODE 16000 - Eval 999 over 1000 - Number of game played 33000 - 1 hour, 13 minutes and 28 seconds
# ########## Evaluation - Episode 16000 ##########
# Timestep: 1281700 Average reward is -2.666
# EPISODE 17000 - Eval 999 over 1000 - Number of game played 35000 - 1 hour, 17 minutes and 59 seconds
# ########## Evaluation - Episode 17000 ##########
# Timestep: 1361930 Average reward is 1.882
# EPISODE 18000 - Eval 999 over 1000 - Number of game played 37000 - 1 hour, 22 minutes and 32 seconds
# ########## Evaluation - Episode 18000 ##########
# Timestep: 1442191 Average reward is -0.271
# EPISODE 19000 - Eval 999 over 1000 - Number of game played 39000 - 1 hour, 27 minutes and 6 secondss
# ########## Evaluation - Episode 19000 ##########
# Timestep: 1522489 Average reward is 0.467
# EPISODE 20000 - Eval 999 over 1000 - Number of game played 41000 - 1 hour, 31 minutes and 41 seconds
# ########## Evaluation - Episode 20000 ##########
# Timestep: 1602816 Average reward is -3.98
# EPISODE 21000 - Eval 999 over 1000 - Number of game played 43000 - 1 hour, 36 minutes and 16 seconds
# ########## Evaluation - Episode 21000 ##########
# Timestep: 1683237 Average reward is 2.734
# EPISODE 22000 - Eval 999 over 1000 - Number of game played 45000 - 1 hour, 40 minutes and 53 seconds
# ########## Evaluation - Episode 22000 ##########
# Timestep: 1763663 Average reward is 0.843
# EPISODE 23000 - Eval 999 over 1000 - Number of game played 47000 - 1 hour, 45 minutes and 27 seconds
# ########## Evaluation - Episode 23000 ##########
# Timestep: 1844034 Average reward is -7.298
# EPISODE 24000 - Eval 999 over 1000 - Number of game played 49000 - 1 hour, 50 minutes and 1 secondds
# ########## Evaluation - Episode 24000 ##########
# Timestep: 1924351 Average reward is 3.122
# EPISODE 25000 - Eval 999 over 1000 - Number of game played 51000 - 1 hour, 54 minutes and 38 seconds
# ########## Evaluation - Episode 25000 ##########
# Timestep: 2004667 Average reward is 1.604
# EPISODE 26000 - Eval 999 over 1000 - Number of game played 53000 - 1 hour, 59 minutes and 14 seconds
# ########## Evaluation - Episode 26000 ##########
# Timestep: 2084967 Average reward is -7.902
# EPISODE 27000 - Eval 999 over 1000 - Number of game played 55000 - 2 hours, 3 minutes and 48 seconds
# ########## Evaluation - Episode 27000 ##########
# Timestep: 2165275 Average reward is 2.925
# EPISODE 28000 - Eval 999 over 1000 - Number of game played 57000 - 2 hours, 8 minutes and 25 seconds
# ########## Evaluation - Episode 28000 ##########
# Timestep: 2245590 Average reward is -9.203
# EPISODE 29000 - Eval 999 over 1000 - Number of game played 59000 - 2 hours, 13 minutes and 3 secondss
# ########## Evaluation - Episode 29000 ##########
# Timestep: 2325816 Average reward is -1.356
# EPISODE 30000 - Eval 999 over 1000 - Number of game played 61000 - 2 hours, 17 minutes and 39 seconds
# ########## Evaluation - Episode 30000 ##########
# Timestep: 2406106 Average reward is 2.74
# EPISODE 31000 - Eval 999 over 1000 - Number of game played 63000 - 2 hours, 22 minutes and 19 seconds
# ########## Evaluation - Episode 31000 ##########
# Timestep: 2486356 Average reward is 2.172
# EPISODE 32000 - Eval 999 over 1000 - Number of game played 65000 - 2 hours, 26 minutes and 59 seconds
# ########## Evaluation - Episode 32000 ##########
# Timestep: 2566638 Average reward is 2.319
# EPISODE 33000 - Eval 999 over 1000 - Number of game played 67000 - 2 hours, 31 minutes and 36 seconds
# ########## Evaluation - Episode 33000 ##########
# Timestep: 2646945 Average reward is 2.267
# EPISODE 34000 - Eval 999 over 1000 - Number of game played 69000 - 2 hours, 36 minutes and 16 seconds
# ########## Evaluation - Episode 34000 ##########
# Timestep: 2727240 Average reward is 0.022
# EPISODE 35000 - Eval 999 over 1000 - Number of game played 71000 - 2 hours, 40 minutes and 53 seconds
# ########## Evaluation - Episode 35000 ##########
# Timestep: 2807576 Average reward is 3.416
# EPISODE 36000 - Eval 999 over 1000 - Number of game played 73000 - 2 hours, 45 minutes and 33 seconds
# ########## Evaluation - Episode 36000 ##########
# Timestep: 2887994 Average reward is 1.101
# EPISODE 37000 - Eval 999 over 1000 - Number of game played 75000 - 2 hours, 50 minutes and 19 seconds
# ########## Evaluation - Episode 37000 ##########
# Timestep: 2968448 Average reward is -1.286
# EPISODE 38000 - Eval 999 over 1000 - Number of game played 77000 - 2 hours, 54 minutes and 59 seconds
# ########## Evaluation - Episode 38000 ##########
# Timestep: 3048847 Average reward is 3.079
# EPISODE 39000 - Eval 999 over 1000 - Number of game played 79000 - 2 hours, 59 minutes and 42 seconds
# ########## Evaluation - Episode 39000 ##########
# Timestep: 3129162 Average reward is 0.423
# EPISODE 40000 - Eval 999 over 1000 - Number of game played 81000 - 3 hours, 4 minutes and 24 seconds
# ########## Evaluation - Episode 40000 ##########
# Timestep: 3209429 Average reward is -2.889
# EPISODE 41000 - Eval 999 over 1000 - Number of game played 83000 - 3 hours, 9 minutes and 6 secondss
# ########## Evaluation - Episode 41000 ##########
# Timestep: 3289813 Average reward is -6.752
# EPISODE 42000 - Eval 999 over 1000 - Number of game played 85000 - 3 hours, 13 minutes and 52 seconds
# ########## Evaluation - Episode 42000 ##########
# Timestep: 3370205 Average reward is -7.755
# EPISODE 43000 - Eval 999 over 1000 - Number of game played 87000 - 3 hours, 18 minutes and 35 seconds
# ########## Evaluation - Episode 43000 ##########
# Timestep: 3450582 Average reward is 3.246
# EPISODE 44000 - Eval 999 over 1000 - Number of game played 89000 - 3 hours, 23 minutes and 25 seconds
# ########## Evaluation - Episode 44000 ##########
# Timestep: 3530913 Average reward is -4.135
# EPISODE 45000 - Eval 999 over 1000 - Number of game played 91000 - 3 hours, 28 minutes and 10 seconds
# ########## Evaluation - Episode 45000 ##########
# Timestep: 3611223 Average reward is 2.17
# EPISODE 46000 - Eval 999 over 1000 - Number of game played 93000 - 3 hours, 32 minutes and 58 seconds
# ########## Evaluation - Episode 46000 ##########
# Timestep: 3691640 Average reward is -2.684
# EPISODE 47000 - Eval 999 over 1000 - Number of game played 95000 - 3 hours, 37 minutes and 46 seconds
# ########## Evaluation - Episode 47000 ##########
# Timestep: 3772025 Average reward is -2.871
# EPISODE 48000 - Eval 999 over 1000 - Number of game played 97000 - 3 hours, 42 minutes and 37 seconds
# ########## Evaluation - Episode 48000 ##########
# Timestep: 3852434 Average reward is -0.447
# EPISODE 49000 - Eval 999 over 1000 - Number of game played 99000 - 3 hours, 47 minutes and 31 seconds
# ########## Evaluation - Episode 49000 ##########
# Timestep: 3932751 Average reward is 0.081
# EPISODE 50000 - Eval 999 over 1000 - Number of game played 101000 - 3 hours, 52 minutes and 23 seconds
# ########## Evaluation - Episode 50000 ##########
# Timestep: 4013089 Average reward is -4.111
# EPISODE 51000 - Eval 999 over 1000 - Number of game played 103000 - 3 hours, 57 minutes and 16 seconds
# ########## Evaluation - Episode 51000 ##########
# Timestep: 4093520 Average reward is -2.713
# EPISODE 52000 - Eval 999 over 1000 - Number of game played 105000 - 4 hours, 2 minutes and 10 seconds
# ########## Evaluation - Episode 52000 ##########
# Timestep: 4173863 Average reward is 0.962
# EPISODE 53000 - Eval 999 over 1000 - Number of game played 107000 - 4 hours, 7 minutes and 4 secondss
# ########## Evaluation - Episode 53000 ##########
# Timestep: 4254272 Average reward is 3.079
# EPISODE 54000 - Eval 999 over 1000 - Number of game played 109000 - 4 hours, 12 minutes and 5 secondss
# ########## Evaluation - Episode 54000 ##########
# Timestep: 4334638 Average reward is -0.969
# EPISODE 55000 - Eval 999 over 1000 - Number of game played 111000 - 4 hours, 17 minutes and 0 secondds
# ########## Evaluation - Episode 55000 ##########
# Timestep: 4414969 Average reward is 0.824
# EPISODE 56000 - Eval 999 over 1000 - Number of game played 113000 - 4 hours, 22 minutes and 0 secondds
# ########## Evaluation - Episode 56000 ##########
# Timestep: 4495337 Average reward is -0.074
# EPISODE 57000 - Eval 999 over 1000 - Number of game played 115000 - 4 hours, 27 minutes and 12 seconds
# ########## Evaluation - Episode 57000 ##########
# Timestep: 4575709 Average reward is -3.449
# EPISODE 58000 - Eval 999 over 1000 - Number of game played 117000 - 4 hours, 32 minutes and 24 seconds
# ########## Evaluation - Episode 58000 ##########
# Timestep: 4656165 Average reward is -3.161
# EPISODE 59000 - Eval 999 over 1000 - Number of game played 119000 - 4 hours, 37 minutes and 18 seconds
# ########## Evaluation - Episode 59000 ##########
# Timestep: 4736581 Average reward is 3.279
# EPISODE 60000 - Eval 999 over 1000 - Number of game played 121000 - 4 hours, 42 minutes and 19 seconds
# ########## Evaluation - Episode 60000 ##########
# Timestep: 4816984 Average reward is 1.036
# EPISODE 61000 - Eval 999 over 1000 - Number of game played 123000 - 4 hours, 47 minutes and 31 seconds
# ########## Evaluation - Episode 61000 ##########
# Timestep: 4897404 Average reward is -1.038
# EPISODE 62000 - Eval 999 over 1000 - Number of game played 125000 - 4 hours, 52 minutes and 56 seconds
# ########## Evaluation - Episode 62000 ##########
# Timestep: 4977770 Average reward is -2.169
# EPISODE 63000 - Eval 999 over 1000 - Number of game played 127000 - 4 hours, 57 minutes and 59 seconds
# ########## Evaluation - Episode 63000 ##########
# Timestep: 5058208 Average reward is 0.28
# EPISODE 64000 - Eval 999 over 1000 - Number of game played 129000 - 5 hours, 3 minutes and 3 secondss
# ########## Evaluation - Episode 64000 ##########
# Timestep: 5138682 Average reward is -7.154
# EPISODE 65000 - Eval 999 over 1000 - Number of game played 131000 - 5 hours, 8 minutes and 7 secondss
# ########## Evaluation - Episode 65000 ##########
# Timestep: 5219052 Average reward is -6.428
# EPISODE 66000 - Eval 999 over 1000 - Number of game played 133000 - 5 hours, 13 minutes and 13 seconds
# ########## Evaluation - Episode 66000 ##########
# Timestep: 5299510 Average reward is -8.091
# EPISODE 67000 - Eval 999 over 1000 - Number of game played 135000 - 5 hours, 18 minutes and 24 seconds
# ########## Evaluation - Episode 67000 ##########
# Timestep: 5379862 Average reward is -2.598
# EPISODE 68000 - Eval 999 over 1000 - Number of game played 137000 - 5 hours, 23 minutes and 37 seconds
# ########## Evaluation - Episode 68000 ##########
# Timestep: 5460246 Average reward is -3.084
# EPISODE 69000 - Eval 999 over 1000 - Number of game played 139000 - 5 hours, 28 minutes and 49 seconds
# ########## Evaluation - Episode 69000 ##########
# Timestep: 5540621 Average reward is 2.479
# EPISODE 70000 - Eval 999 over 1000 - Number of game played 141000 - 5 hours, 33 minutes and 59 seconds
# ########## Evaluation - Episode 70000 ##########
# Timestep: 5620981 Average reward is -5.285
# EPISODE 71000 - Eval 999 over 1000 - Number of game played 143000 - 5 hours, 39 minutes and 16 seconds
# ########## Evaluation - Episode 71000 ##########
# Timestep: 5701409 Average reward is -3.52
# EPISODE 72000 - Eval 999 over 1000 - Number of game played 145000 - 5 hours, 44 minutes and 39 seconds
# ########## Evaluation - Episode 72000 ##########
# Timestep: 5781841 Average reward is -1.215
# EPISODE 73000 - Eval 999 over 1000 - Number of game played 147000 - 5 hours, 49 minutes and 54 seconds
# ########## Evaluation - Episode 73000 ##########
# Timestep: 5862318 Average reward is -2.59
# EPISODE 74000 - Eval 999 over 1000 - Number of game played 149000 - 5 hours, 55 minutes and 8 secondss
# ########## Evaluation - Episode 74000 ##########
# Timestep: 5942467 Average reward is 1.667
# EPISODE 75000 - Eval 999 over 1000 - Number of game played 151000 - 6 hours, 0 minute and 20 secondsds
# ########## Evaluation - Episode 75000 ##########
# Timestep: 6022479 Average reward is -3.581
# EPISODE 76000 - Eval 999 over 1000 - Number of game played 153000 - 6 hours, 5 minutes and 37 seconds
# ########## Evaluation - Episode 76000 ##########
# Timestep: 6102781 Average reward is -0.874
# EPISODE 77000 - Eval 999 over 1000 - Number of game played 155000 - 6 hours, 10 minutes and 50 seconds
# ########## Evaluation - Episode 77000 ##########
# Timestep: 6182998 Average reward is 3.257
# EPISODE 78000 - Eval 999 over 1000 - Number of game played 157000 - 6 hours, 16 minutes and 7 secondss
# ########## Evaluation - Episode 78000 ##########
# Timestep: 6263318 Average reward is 3.072
# EPISODE 79000 - Eval 999 over 1000 - Number of game played 159000 - 6 hours, 21 minutes and 29 seconds
# ########## Evaluation - Episode 79000 ##########
# Timestep: 6343800 Average reward is -2.763
# EPISODE 80000 - Eval 999 over 1000 - Number of game played 161000 - 6 hours, 26 minutes and 58 seconds
# ########## Evaluation - Episode 80000 ##########
# Timestep: 6424283 Average reward is -2.272
# EPISODE 81000 - Eval 999 over 1000 - Number of game played 163000 - 6 hours, 32 minutes and 20 seconds
# ########## Evaluation - Episode 81000 ##########
# Timestep: 6504632 Average reward is -1.678
# EPISODE 82000 - Eval 999 over 1000 - Number of game played 165000 - 6 hours, 37 minutes and 46 seconds
# ########## Evaluation - Episode 82000 ##########
# Timestep: 6584999 Average reward is -3.011
# EPISODE 83000 - Eval 999 over 1000 - Number of game played 167000 - 6 hours, 43 minutes and 11 seconds
# ########## Evaluation - Episode 83000 ##########
# Timestep: 6665163 Average reward is -5.459
# EPISODE 84000 - Eval 999 over 1000 - Number of game played 169000 - 6 hours, 48 minutes and 30 seconds
# ########## Evaluation - Episode 84000 ##########
# Timestep: 6745134 Average reward is -7.327
# EPISODE 85000 - Eval 999 over 1000 - Number of game played 171000 - 6 hours, 53 minutes and 53 seconds
# ########## Evaluation - Episode 85000 ##########
# Timestep: 6825132 Average reward is -6.626
# EPISODE 86000 - Eval 999 over 1000 - Number of game played 173000 - 6 hours, 59 minutes and 17 seconds
# ########## Evaluation - Episode 86000 ##########
# Timestep: 6905089 Average reward is -6.288
# EPISODE 87000 - Eval 999 over 1000 - Number of game played 175000 - 7 hours, 4 minutes and 43 seconds
# ########## Evaluation - Episode 87000 ##########
# Timestep: 6984990 Average reward is -4.377
# EPISODE 88000 - Eval 999 over 1000 - Number of game played 177000 - 7 hours, 10 minutes and 9 seconds
# ########## Evaluation - Episode 88000 ##########
# Timestep: 7064841 Average reward is -4.821
# EPISODE 89000 - Eval 999 over 1000 - Number of game played 179000 - 7 hours, 15 minutes and 37 seconds
# ########## Evaluation - Episode 89000 ##########
# Timestep: 7144680 Average reward is -4.906
# EPISODE 90000 - Eval 999 over 1000 - Number of game played 181000 - 7 hours, 21 minutes and 8 secondss
# ########## Evaluation - Episode 90000 ##########
# Timestep: 7224566 Average reward is -3.745
# EPISODE 91000 - Eval 999 over 1000 - Number of game played 183000 - 7 hours, 26 minutes and 40 seconds
# ########## Evaluation - Episode 91000 ##########
# Timestep: 7304400 Average reward is -6.063
# EPISODE 92000 - Eval 999 over 1000 - Number of game played 185000 - 7 hours, 32 minutes and 15 seconds
# ########## Evaluation - Episode 92000 ##########
# Timestep: 7384213 Average reward is -4.314
# EPISODE 93000 - Eval 999 over 1000 - Number of game played 187000 - 7 hours, 37 minutes and 51 seconds
# ########## Evaluation - Episode 93000 ##########
# Timestep: 7464038 Average reward is -5.247
# EPISODE 94000 - Eval 999 over 1000 - Number of game played 189000 - 7 hours, 43 minutes and 27 seconds
# ########## Evaluation - Episode 94000 ##########
# Timestep: 7543840 Average reward is -7.455
# EPISODE 95000 - Eval 999 over 1000 - Number of game played 191000 - 7 hours, 49 minutes and 5 secondss
# ########## Evaluation - Episode 95000 ##########
# Timestep: 7623637 Average reward is -7.446
# EPISODE 96000 - Eval 999 over 1000 - Number of game played 193000 - 7 hours, 54 minutes and 46 seconds
# ########## Evaluation - Episode 96000 ##########
# Timestep: 7703528 Average reward is -7.781
# EPISODE 97000 - Eval 999 over 1000 - Number of game played 195000 - 8 hours, 0 minute and 29 secondsds
# ########## Evaluation - Episode 97000 ##########
# Timestep: 7783321 Average reward is -9.599
# EPISODE 98000 - Eval 999 over 1000 - Number of game played 197000 - 8 hours, 6 minutes and 13 seconds
# ########## Evaluation - Episode 98000 ##########
# Timestep: 7863252 Average reward is -8.959
# EPISODE 99000 - Eval 999 over 1000 - Number of game played 199000 - 8 hours, 11 minutes and 58 seconds
# ########## Evaluation - Episode 99000 ##########
# Timestep: 7943042 Average reward is -9.0
# EPISODE 99999 - Number of game played 199999 - 8 hours, 16 minutes and 36 seconds

# %%
# %cd ..
# Out:
# /home/jovyan/personal_project/RL-tarot

# %%
import warnings
warnings.simplefilter('ignore')

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

import tensorflow as tf
tf.get_logger().setLevel('INFO')
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
warnings.filterwarnings('ignore')
"""
An example of learning a Deep-Q Agent on French Tarot Game
"""
import os
import time

import tensorflow as tf

import rlcard
from rlcard.agents.dqn_agent import DQNAgent
from rlcard.agents.random_agent import RandomAgent
from rlcard.utils.logger import Logger
from rlcard.utils.utils import time_difference_good_format

record_number = 15

# Make environment
env = rlcard.make('tarot')
eval_env = rlcard.make('tarot')

# Set the iterations numbers and how frequently we evaluate/save plot
evaluate_every = 100
evaluate_num = 1000
episode_num = 100000
# Train against
train_against = 'random'  # or 'same'

# Set the the number of steps for collecting normalization statistics
# and intial memory size
memory_init_size = 5000
norm_step = 1000

# The paths for saving the logs and learning curves
root_path = './experiments/{}_played_{}/'.format(train_against, str(record_number))
log_path_random = root_path + 'log_random.txt'
csv_path_random = root_path + 'performance_random.csv'
figure_path_random = root_path + 'figures_random/'

# Model save path
if not os.path.exists('rlcard/models'):
    os.makedirs('rlcard/models')
if not os.path.exists('rlcard/models/pretrained'):
    os.makedirs('rlcard/models/pretrained')
for eval_number in range(1, episode_num // evaluate_every + 1):
    model_folder_path = 'rlcard/models/pretrained/{}_played_{}/tarot_v{}'.format(train_against,
                                                                                 str(record_number),
                                                                                 str(
                                                                                     record_number * 10000 + eval_number))
    if not os.path.exists(model_folder_path):
        os.makedirs(model_folder_path)
model_path = 'rlcard/models/pretrained/{}_played_{}/tarot_v{}/model'.format(train_against,
                                                                            str(record_number),
                                                                            str(record_number * 10000))

random_agent = RandomAgent(action_num=78)

with tf.compat.v1.Session() as sess:
    # Set agents
    global_step = tf.Variable(0, name='global_step', trainable=False)
    agent = DQNAgent(sess,
                     scope='dqn',
                     action_num=78,  # env.action_num,
                     replay_memory_size=20000,
                     replay_memory_init_size=memory_init_size,
                     norm_step=norm_step,
                     state_shape=env.state_shape,
                     mlp_layers=[512, 1024, 512])

    sess.run(tf.compat.v1.global_variables_initializer())

    saver = tf.compat.v1.train.Saver(max_to_keep=None)
    if train_against == 'random':
        env.set_agents([agent] + [random_agent] * (env.player_num - 1))
    else:
        env.set_agents([agent] + [agent] * (env.player_num - 1))

    eval_env.set_agents([agent] + [random_agent] * (env.player_num - 1))

    # Count the number of steps
    step_counter = 0

    # Init a Logger to plot the learning curve against random
    logger_random = Logger(xlabel='episode', ylabel='reward', legend='DQN on TAROT against Random',
                           legend_hist='Histogram of last evaluations against Random', log_path=log_path_random,
                           csv_path=csv_path_random)

    total_game_played = 0
    seconds = time.time()

    for episode in range(episode_num):
        # Evaluate the performance.
        if episode % evaluate_every == 0:
            # Save Model

            model_path = 'rlcard/models/pretrained/{}_played_{}/tarot_v{}/model'.format(train_against,
                                                                                        str(record_number),
                                                                                        str(
                                                                                            record_number * 10000 + episode // evaluate_every))

            saver.save(sess, model_path)

            # Eval against random
            reward_random = 0
            reward_random_list = []
            taking_list = []
            for eval_episode in range(evaluate_num):
                print('\rEPISODE {} - Eval Random {} over {} - Number of game played {} - {}'.format(episode,
                                                                                                     eval_episode,
                                                                                                     evaluate_num,
                                                                                                     total_game_played,
                                                                                                     time_difference_good_format(
                                                                                                         seconds,
                                                                                                         time.time())),
                      end='')
                _, payoffs = eval_env.run(is_training=False)
                total_game_played += 1
                reward_random_list.append(payoffs[0])
                reward_random += payoffs[0]
                taking_list.append(eval_env.game.players[0].taking)

            logger_random.log('\n########## Evaluation Against Random - Episode {} ##########'.format(episode))
            logger_random.log(
                'Timestep: {} Average reward against random is {}'.format(env.timestep,
                                                                          float(reward_random) / evaluate_num))

            # Add point to logger
            logger_random.add_point(x=episode, y=float(reward_random) / evaluate_num)

            # Make plot
            logger_random.make_plot(save_path=figure_path_random + str(episode) + '.png')
            logger_random.make_plot_hist(save_path_1=figure_path_random + str(episode) + '_hist.png',
                                         save_path_2=figure_path_random + str(episode) + '_freq.png',
                                         reward_list=reward_random_list, taking_list=taking_list)

        print('\rEPISODE {} - Number of game played {} - {}'.format(episode, total_game_played,
                                                                    time_difference_good_format(seconds,
                                                                                                time.time())),
              end='')

        # Generate data from the environment
        trajectories, _ = env.run(is_training=True)
        total_game_played += 1

        # Feed transitions into agent memory, and train the agent
        for ts in trajectories[0]:
            agent.feed(ts)
            step_counter += 1

            # Train the agent
            train_count = step_counter - (memory_init_size + norm_step)
            if train_count > 0:
                loss = agent.train()
                # print('\rINFO - Step {}, loss: {}'.format(step_counter, loss), end='')

    # Make the final plot
    logger_random.make_plot(save_path=figure_path_random + 'final_' + str(episode) + '.png')
    logger_random.make_plot_hist(save_path_1=figure_path_random + str(episode) + '_hist.png',
                                 save_path_2=figure_path_random + str(episode) + '_freq.png',
                                 reward_list=reward_random_list, taking_list=taking_list)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# EPISODE 0 - Eval Random 999 over 1000 - Number of game played 999 - 34 seconds
# ########## Evaluation Against Random - Episode 0 ##########
# Timestep: 0 Average reward against random is -3.207
# EPISODE 100 - Eval Random 999 over 1000 - Number of game played 2099 - 1 minute and 16 seconds
# ########## Evaluation Against Random - Episode 100 ##########
# Timestep: 8011 Average reward against random is -3.118
# EPISODE 200 - Eval Random 999 over 1000 - Number of game played 3199 - 1 minute and 56 seconds
# ########## Evaluation Against Random - Episode 200 ##########
# Timestep: 16018 Average reward against random is -3.582
# EPISODE 300 - Eval Random 999 over 1000 - Number of game played 4299 - 2 minutes and 37 seconds
# ########## Evaluation Against Random - Episode 300 ##########
# Timestep: 24012 Average reward against random is -1.87
# EPISODE 400 - Eval Random 999 over 1000 - Number of game played 5399 - 3 minutes and 35 seconds
# ########## Evaluation Against Random - Episode 400 ##########
# Timestep: 32003 Average reward against random is -3.309
# EPISODE 500 - Eval Random 999 over 1000 - Number of game played 6499 - 4 minutes and 35 seconds
# ########## Evaluation Against Random - Episode 500 ##########
# Timestep: 39999 Average reward against random is -2.548
# EPISODE 600 - Eval Random 999 over 1000 - Number of game played 7599 - 5 minutes and 33 seconds
# ########## Evaluation Against Random - Episode 600 ##########
# Timestep: 47995 Average reward against random is -1.312
# EPISODE 700 - Eval Random 999 over 1000 - Number of game played 8699 - 6 minutes and 31 seconds
# ########## Evaluation Against Random - Episode 700 ##########
# Timestep: 55994 Average reward against random is -1.413
# EPISODE 800 - Eval Random 999 over 1000 - Number of game played 9799 - 7 minutes and 29 seconds
# ########## Evaluation Against Random - Episode 800 ##########
# Timestep: 63986 Average reward against random is -0.737
# EPISODE 900 - Eval Random 999 over 1000 - Number of game played 10899 - 8 minutes and 30 seconds
# ########## Evaluation Against Random - Episode 900 ##########
# Timestep: 71961 Average reward against random is -3.104
# EPISODE 1000 - Eval Random 999 over 1000 - Number of game played 11999 - 9 minutes and 30 seconds
# ########## Evaluation Against Random - Episode 1000 ##########
# Timestep: 79951 Average reward against random is -0.368
# EPISODE 1100 - Eval Random 999 over 1000 - Number of game played 13099 - 10 minutes and 30 seconds
# ########## Evaluation Against Random - Episode 1100 ##########
# Timestep: 87936 Average reward against random is -0.457
# EPISODE 1200 - Eval Random 999 over 1000 - Number of game played 14199 - 11 minutes and 32 seconds
# ########## Evaluation Against Random - Episode 1200 ##########
# Timestep: 95916 Average reward against random is -3.62
# EPISODE 1300 - Eval Random 999 over 1000 - Number of game played 15299 - 12 minutes and 34 seconds
# ########## Evaluation Against Random - Episode 1300 ##########
# Timestep: 103935 Average reward against random is -4.274
# EPISODE 1400 - Eval Random 999 over 1000 - Number of game played 16399 - 13 minutes and 35 seconds
# ########## Evaluation Against Random - Episode 1400 ##########
# Timestep: 111937 Average reward against random is -1.576
# EPISODE 1500 - Eval Random 999 over 1000 - Number of game played 17499 - 14 minutes and 34 seconds
# ########## Evaluation Against Random - Episode 1500 ##########
# Timestep: 119929 Average reward against random is 2.191
# EPISODE 1600 - Eval Random 999 over 1000 - Number of game played 18599 - 15 minutes and 37 seconds
# ########## Evaluation Against Random - Episode 1600 ##########
# Timestep: 127931 Average reward against random is -7.215
# EPISODE 1700 - Eval Random 999 over 1000 - Number of game played 19699 - 16 minutes and 40 seconds
# ########## Evaluation Against Random - Episode 1700 ##########
# Timestep: 135944 Average reward against random is -7.236
# EPISODE 1800 - Eval Random 999 over 1000 - Number of game played 20799 - 17 minutes and 41 seconds
# ########## Evaluation Against Random - Episode 1800 ##########
# Timestep: 143956 Average reward against random is -6.992
# EPISODE 1900 - Eval Random 999 over 1000 - Number of game played 21899 - 18 minutes and 43 seconds
# ########## Evaluation Against Random - Episode 1900 ##########
# Timestep: 151966 Average reward against random is -6.72
# EPISODE 2000 - Eval Random 999 over 1000 - Number of game played 22999 - 19 minutes and 41 seconds
# ########## Evaluation Against Random - Episode 2000 ##########
# Timestep: 159981 Average reward against random is 2.247
# EPISODE 2100 - Eval Random 999 over 1000 - Number of game played 24099 - 20 minutes and 38 seconds
# ########## Evaluation Against Random - Episode 2100 ##########
# Timestep: 167977 Average reward against random is 2.282
# EPISODE 2200 - Eval Random 999 over 1000 - Number of game played 25199 - 21 minutes and 35 seconds
# ########## Evaluation Against Random - Episode 2200 ##########
# Timestep: 175974 Average reward against random is 2.478
# EPISODE 2300 - Eval Random 999 over 1000 - Number of game played 26299 - 22 minutes and 31 seconds
# ########## Evaluation Against Random - Episode 2300 ##########
# Timestep: 183967 Average reward against random is 2.378
# EPISODE 2400 - Eval Random 999 over 1000 - Number of game played 27399 - 23 minutes and 34 seconds
# ########## Evaluation Against Random - Episode 2400 ##########
# Timestep: 191965 Average reward against random is -7.374
# EPISODE 2500 - Eval Random 870 over 1000 - Number of game played 28370 - 24 minutes and 27 seconds

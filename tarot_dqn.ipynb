# %%
"""
An example of learning a Deep-Q Agent on French Tarot Game
"""
import os
import time

import tensorflow as tf

import rlcard
from rlcard.agents.dqn_agent import DQNAgent
from rlcard.agents.random_agent import RandomAgent
from rlcard.utils.logger import Logger
from rlcard.utils.utils import set_global_seed, time_difference_good_format

# Make environment
env = rlcard.make('tarot')
eval_env = rlcard.make('tarot')

# Set the iterations numbers and how frequently we evaluate/save plot
evaluate_every = 100
save_plot_every = 100
evaluate_num = 100
episode_num = 10000

record_number = 9

# Set the the number of steps for collecting normalization statistics
# and intial memory size
memory_init_size = 5000
norm_step = 1000

# The paths for saving the logs and learning curves
root_path = './experiments/tarot_dqn_result_v{}/'.format(str(record_number))
log_path = root_path + 'log.txt'
csv_path = root_path + 'performance.csv'
figure_path = root_path + 'figures/'

# Model save path
if not os.path.exists('rlcard/models'):
    os.makedirs('rlcard/models')
    if not os.path.exists('rlcard/models/pretrained'):
        os.makedirs('rlcard/models/pretrained')
        if not os.path.exists('rlcard/models/pretrained/tarot_v' + str(record_number)):
            os.makedirs('rlcard/models/pretrained/tarot_v' + str(record_number))
model_path = 'rlcard/models/pretrained/tarot_v' + str(record_number) + '/model'

# Set a global seed
set_global_seed(0)

with tf.compat.v1.Session() as sess:
    # Set agents
    global_step = tf.Variable(0, name='global_step', trainable=False)
    agent = DQNAgent(sess,
                     scope='dqn',
                     action_num=78,  # env.action_num,
                     replay_memory_size=20000,
                     replay_memory_init_size=memory_init_size,
                     norm_step=norm_step,
                     state_shape=env.state_shape,
                     mlp_layers=[512, 512])

    random_agent = RandomAgent(action_num=eval_env.action_num)

    sess.run(tf.compat.v1.global_variables_initializer())

    saver = tf.compat.v1.train.Saver()

    env.set_agents([agent] + [random_agent] * (env.player_num - 1))
    eval_env.set_agents([agent] + [random_agent] * (env.player_num - 1))

    # Count the number of steps
    step_counter = 0

    total_game_played = 0
    seconds = time.time()

    # Init a Logger to plot the learning curve
    logger = Logger(xlabel='timestep', ylabel='reward', legend='DQN on TAROT', log_path=log_path, csv_path=csv_path)

    for episode in range(episode_num):
        print('\rEPISODE {} - Number of game played {} - {}'.format(episode, total_game_played,
                                                                    time_difference_good_format(seconds, time.time())),
              end='')

        # Generate data from the environment
        trajectories, _ = env.run(is_training=True)
        total_game_played += 1

        # Feed transitions into agent memory, and train the agent
        for ts in trajectories[0]:
            agent.feed(ts)
            step_counter += 1

            # Train the agent
            train_count = step_counter - (memory_init_size + norm_step)
            if train_count > 0:
                loss = agent.train()
                #print('\rINFO - Step {}, loss: {}'.format(step_counter, loss), end='')

        # Evaluate the performance. Play with random agents.
        if episode % evaluate_every == 0:
            # Save Model
            saver.save(sess, model_path)
            reward = 0
            for eval_episode in range(evaluate_num):
                print('\rEPISODE {} - Eval {} over {} - Number of game played {} - {}'.format(episode, eval_episode,
                                                                                              evaluate_num,
                                                                                              total_game_played,
                                                                                              time_difference_good_format(
                                                                                                  seconds,
                                                                                                  time.time())),
                      end='')
                _, payoffs = eval_env.run(is_training=False)
                total_game_played += 1
                reward += payoffs[0]

            logger.log('\n########## Evaluation - Episode {} ##########'.format(episode))
            logger.log('Timestep: {} Average reward is {}'.format(env.timestep, float(reward) / evaluate_num))

            # Add point to logger
            logger.add_point(x=env.timestep, y=float(reward) / evaluate_num)

        # Make plot
        if episode % save_plot_every == 0 and episode > 0:
            logger.make_plot(save_path=figure_path + str(episode) + '.png')

    # Make the final plot
    logger.make_plot(save_path=figure_path + 'final_' + str(episode) + '.png')
# Out:
# tarot-rule-v1
# rlcard.models.tarot_rule_models:TAROTRuleModelV1
# tarot-bid-rule-v1
# rlcard.models.tarot_bid_rule_models:TAROTBIDRuleModelV1
# tarot-dog-rule-v1
# rlcard.models.tarot_dog_rule_models:TAROTDOGRuleModelV1
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# EPISODE 0 - Eval 99 over 100 - Number of game played 100 - 8 seconds
# ########## Evaluation - Episode 0 ##########
# Timestep: 81 Average reward is 0.2
# EPISODE 100 - Eval 99 over 100 - Number of game played 300 - 35 seconds
# ########## Evaluation - Episode 100 ##########
# Timestep: 8088 Average reward is 3.38
# EPISODE 200 - Eval 99 over 100 - Number of game played 500 - 1 minute and 20 seconds
# ########## Evaluation - Episode 200 ##########
# Timestep: 16136 Average reward is 3.3
# EPISODE 300 - Eval 99 over 100 - Number of game played 700 - 2 minutes and 27 seconds
# ########## Evaluation - Episode 300 ##########
# Timestep: 24148 Average reward is 0.01
# EPISODE 400 - Eval 99 over 100 - Number of game played 900 - 4 minutes and 1 secondds
# ########## Evaluation - Episode 400 ##########
# Timestep: 32193 Average reward is 2.69
# EPISODE 500 - Eval 99 over 100 - Number of game played 1100 - 5 minutes and 53 seconds
# ########## Evaluation - Episode 500 ##########
# Timestep: 40288 Average reward is 2.34
# EPISODE 600 - Eval 99 over 100 - Number of game played 1300 - 8 minutes and 3 secondss
# ########## Evaluation - Episode 600 ##########
# Timestep: 48383 Average reward is -2.42
# EPISODE 700 - Eval 99 over 100 - Number of game played 1500 - 10 minutes and 32 seconds
# ########## Evaluation - Episode 700 ##########
# Timestep: 56450 Average reward is 1.14
# EPISODE 800 - Eval 99 over 100 - Number of game played 1700 - 13 minutes and 18 seconds
# ########## Evaluation - Episode 800 ##########
# Timestep: 64489 Average reward is 0.57
# EPISODE 900 - Eval 99 over 100 - Number of game played 1900 - 16 minutes and 20 seconds
# ########## Evaluation - Episode 900 ##########
# Timestep: 72577 Average reward is 2.33
# EPISODE 1000 - Eval 99 over 100 - Number of game played 2100 - 19 minutes and 37 seconds
# ########## Evaluation - Episode 1000 ##########
# Timestep: 80673 Average reward is 2.89
# EPISODE 1100 - Eval 99 over 100 - Number of game played 2300 - 23 minutes and 11 seconds
# ########## Evaluation - Episode 1100 ##########
# Timestep: 88781 Average reward is 2.86
# EPISODE 1200 - Eval 99 over 100 - Number of game played 2500 - 27 minutes and 5 secondss
# ########## Evaluation - Episode 1200 ##########
# Timestep: 96877 Average reward is 1.77
# EPISODE 1300 - Eval 99 over 100 - Number of game played 2700 - 31 minutes and 15 seconds
# ########## Evaluation - Episode 1300 ##########
# Timestep: 104980 Average reward is 2.65
# EPISODE 1400 - Eval 99 over 100 - Number of game played 2900 - 35 minutes and 45 seconds
# ########## Evaluation - Episode 1400 ##########
# Timestep: 113068 Average reward is 1.98
# EPISODE 1500 - Eval 99 over 100 - Number of game played 3100 - 40 minutes and 34 seconds
# ########## Evaluation - Episode 1500 ##########
# Timestep: 121150 Average reward is 2.36
# EPISODE 1600 - Eval 99 over 100 - Number of game played 3300 - 45 minutes and 41 seconds
# ########## Evaluation - Episode 1600 ##########
# Timestep: 129212 Average reward is 2.36
# EPISODE 1700 - Eval 99 over 100 - Number of game played 3500 - 51 minutes and 9 secondss
# ########## Evaluation - Episode 1700 ##########
# Timestep: 137264 Average reward is 2.96
# EPISODE 1800 - Eval 99 over 100 - Number of game played 3700 - 56 minutes and 56 seconds
# ########## Evaluation - Episode 1800 ##########
# Timestep: 145307 Average reward is 2.49
# EPISODE 1900 - Eval 99 over 100 - Number of game played 3900 - 1 hour, 2 minutes and 59 seconds
# ########## Evaluation - Episode 1900 ##########
# Timestep: 153343 Average reward is 2.3
# EPISODE 2000 - Eval 99 over 100 - Number of game played 4100 - 1 hour, 9 minutes and 21 seconds
# ########## Evaluation - Episode 2000 ##########
# Timestep: 161372 Average reward is 2.6
# EPISODE 2100 - Eval 99 over 100 - Number of game played 4300 - 1 hour, 16 minutes and 1 secondds
# ########## Evaluation - Episode 2100 ##########
# Timestep: 169408 Average reward is 1.89
# EPISODE 2101 - Number of game played 4301 - 1 hour, 16 minutes and 3 seconds
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# EPISODE 2200 - Eval 99 over 100 - Number of game played 4500 - 1 hour, 22 minutes and 58 seconds
# ########## Evaluation - Episode 2200 ##########
# Timestep: 177459 Average reward is 2.51
# EPISODE 2300 - Eval 99 over 100 - Number of game played 4700 - 1 hour, 30 minutes and 14 seconds
# ########## Evaluation - Episode 2300 ##########
# Timestep: 185514 Average reward is 2.69
# EPISODE 2400 - Eval 99 over 100 - Number of game played 4900 - 1 hour, 37 minutes and 49 seconds
# ########## Evaluation - Episode 2400 ##########
# Timestep: 193535 Average reward is 2.61
# EPISODE 2500 - Eval 99 over 100 - Number of game played 5100 - 1 hour, 45 minutes and 39 seconds
# ########## Evaluation - Episode 2500 ##########
# Timestep: 201574 Average reward is 2.44
# EPISODE 2600 - Eval 99 over 100 - Number of game played 5300 - 1 hour, 53 minutes and 48 seconds
# ########## Evaluation - Episode 2600 ##########
# Timestep: 209590 Average reward is 3.18
# EPISODE 2700 - Eval 99 over 100 - Number of game played 5500 - 2 hours, 2 minutes and 18 seconds
# ########## Evaluation - Episode 2700 ##########
# Timestep: 217616 Average reward is 2.84
# EPISODE 2800 - Eval 99 over 100 - Number of game played 5700 - 2 hours, 11 minutes and 2 secondss
# ########## Evaluation - Episode 2800 ##########
# Timestep: 225643 Average reward is 3.08
# EPISODE 2900 - Eval 99 over 100 - Number of game played 5900 - 2 hours, 20 minutes and 9 secondss
# ########## Evaluation - Episode 2900 ##########
# Timestep: 233675 Average reward is 2.59
# EPISODE 3000 - Eval 99 over 100 - Number of game played 6100 - 2 hours, 29 minutes and 36 seconds
# ########## Evaluation - Episode 3000 ##########
# Timestep: 241708 Average reward is 2.72
# EPISODE 3100 - Eval 99 over 100 - Number of game played 6300 - 2 hours, 39 minutes and 27 seconds
# ########## Evaluation - Episode 3100 ##########
# Timestep: 249732 Average reward is 2.62
# EPISODE 3200 - Eval 99 over 100 - Number of game played 6500 - 2 hours, 49 minutes and 36 seconds
# ########## Evaluation - Episode 3200 ##########
# Timestep: 257772 Average reward is 2.88
# EPISODE 3300 - Eval 99 over 100 - Number of game played 6700 - 3 hours, 0 minute and 1 secondonds
# ########## Evaluation - Episode 3300 ##########
# Timestep: 265792 Average reward is 2.86
# EPISODE 3400 - Eval 99 over 100 - Number of game played 6900 - 3 hours, 10 minutes and 47 seconds
# ########## Evaluation - Episode 3400 ##########
# Timestep: 273825 Average reward is 2.12
# EPISODE 3500 - Eval 99 over 100 - Number of game played 7100 - 3 hours, 21 minutes and 48 seconds
# ########## Evaluation - Episode 3500 ##########
# Timestep: 281852 Average reward is 3.13
# EPISODE 3600 - Eval 99 over 100 - Number of game played 7300 - 3 hours, 33 minutes and 9 secondss
# ########## Evaluation - Episode 3600 ##########
# Timestep: 289886 Average reward is 2.7
# EPISODE 3700 - Eval 99 over 100 - Number of game played 7500 - 3 hours, 44 minutes and 47 seconds
# ########## Evaluation - Episode 3700 ##########
# Timestep: 297910 Average reward is 2.97
# EPISODE 3800 - Eval 99 over 100 - Number of game played 7700 - 3 hours, 56 minutes and 40 seconds
# ########## Evaluation - Episode 3800 ##########
# Timestep: 305943 Average reward is 2.04
# EPISODE 3900 - Eval 99 over 100 - Number of game played 7900 - 4 hours, 8 minutes and 42 seconds
# ########## Evaluation - Episode 3900 ##########
# Timestep: 313963 Average reward is 2.59
# EPISODE 4000 - Eval 99 over 100 - Number of game played 8100 - 4 hours, 21 minutes and 0 secondds
# ########## Evaluation - Episode 4000 ##########
# Timestep: 321997 Average reward is 2.04
# EPISODE 4100 - Eval 99 over 100 - Number of game played 8300 - 4 hours, 33 minutes and 35 seconds
# ########## Evaluation - Episode 4100 ##########
# Timestep: 330015 Average reward is 2.21
# EPISODE 4200 - Eval 99 over 100 - Number of game played 8500 - 4 hours, 46 minutes and 30 seconds
# ########## Evaluation - Episode 4200 ##########
# Timestep: 338047 Average reward is 1.2
# EPISODE 4300 - Eval 99 over 100 - Number of game played 8700 - 4 hours, 59 minutes and 38 seconds
# ########## Evaluation - Episode 4300 ##########
# Timestep: 346070 Average reward is 2.82
# EPISODE 4400 - Eval 99 over 100 - Number of game played 8900 - 5 hours, 13 minutes and 8 secondss
# ########## Evaluation - Episode 4400 ##########
# Timestep: 354103 Average reward is 0.78
# EPISODE 4500 - Eval 99 over 100 - Number of game played 9100 - 5 hours, 27 minutes and 0 secondds
# ########## Evaluation - Episode 4500 ##########
# Timestep: 362141 Average reward is -10.02
# EPISODE 4600 - Eval 99 over 100 - Number of game played 9300 - 5 hours, 41 minutes and 13 seconds
# ########## Evaluation - Episode 4600 ##########
# Timestep: 370152 Average reward is -11.96
# EPISODE 4700 - Eval 99 over 100 - Number of game played 9500 - 5 hours, 55 minutes and 36 seconds
# ########## Evaluation - Episode 4700 ##########
# Timestep: 378189 Average reward is -12.69
# EPISODE 4800 - Eval 99 over 100 - Number of game played 9700 - 6 hours, 10 minutes and 18 seconds
# ########## Evaluation - Episode 4800 ##########
# Timestep: 386212 Average reward is -10.05
# EPISODE 4900 - Eval 99 over 100 - Number of game played 9900 - 6 hours, 25 minutes and 20 seconds
# ########## Evaluation - Episode 4900 ##########
# Timestep: 394229 Average reward is -10.29
# EPISODE 5000 - Eval 99 over 100 - Number of game played 10100 - 6 hours, 40 minutes and 36 seconds
# ########## Evaluation - Episode 5000 ##########
# Timestep: 402262 Average reward is 2.8
# EPISODE 5100 - Eval 99 over 100 - Number of game played 10300 - 6 hours, 56 minutes and 12 seconds
# ########## Evaluation - Episode 5100 ##########
# Timestep: 410280 Average reward is 2.3
# EPISODE 5200 - Eval 99 over 100 - Number of game played 10500 - 7 hours, 12 minutes and 8 secondss
# ########## Evaluation - Episode 5200 ##########
# Timestep: 418287 Average reward is 3.08
# EPISODE 5300 - Eval 99 over 100 - Number of game played 10700 - 7 hours, 28 minutes and 17 seconds
# ########## Evaluation - Episode 5300 ##########
# Timestep: 426302 Average reward is 2.38
# EPISODE 5400 - Eval 99 over 100 - Number of game played 10900 - 7 hours, 44 minutes and 44 seconds
# ########## Evaluation - Episode 5400 ##########
# Timestep: 434327 Average reward is 2.46
# EPISODE 5500 - Eval 99 over 100 - Number of game played 11100 - 8 hours, 1 minute and 29 secondsds
# ########## Evaluation - Episode 5500 ##########
# Timestep: 442341 Average reward is 2.8
# EPISODE 5600 - Eval 99 over 100 - Number of game played 11300 - 8 hours, 18 minutes and 42 seconds
# ########## Evaluation - Episode 5600 ##########
# Timestep: 450371 Average reward is 2.54
# EPISODE 5700 - Eval 99 over 100 - Number of game played 11500 - 8 hours, 36 minutes and 13 seconds
# ########## Evaluation - Episode 5700 ##########
# Timestep: 458399 Average reward is 1.84
# EPISODE 5800 - Eval 99 over 100 - Number of game played 11700 - 8 hours, 54 minutes and 1 secondds
# ########## Evaluation - Episode 5800 ##########
# Timestep: 466437 Average reward is 2.71
# EPISODE 5900 - Eval 99 over 100 - Number of game played 11900 - 9 hours, 12 minutes and 10 seconds
# ########## Evaluation - Episode 5900 ##########
# Timestep: 474464 Average reward is 2.06
# EPISODE 6000 - Eval 99 over 100 - Number of game played 12100 - 9 hours, 30 minutes and 35 seconds
# ########## Evaluation - Episode 6000 ##########
# Timestep: 482488 Average reward is 2.89
# EPISODE 6100 - Eval 99 over 100 - Number of game played 12300 - 9 hours, 49 minutes and 23 seconds
# ########## Evaluation - Episode 6100 ##########
# Timestep: 490508 Average reward is 2.65
# EPISODE 6200 - Eval 99 over 100 - Number of game played 12500 - 10 hours, 8 minutes and 29 seconds
# ########## Evaluation - Episode 6200 ##########
# Timestep: 498544 Average reward is 2.37
# EPISODE 6300 - Eval 99 over 100 - Number of game played 12700 - 10 hours, 27 minutes and 46 seconds
# ########## Evaluation - Episode 6300 ##########
# Timestep: 506576 Average reward is 2.46
# EPISODE 6400 - Eval 99 over 100 - Number of game played 12900 - 10 hours, 47 minutes and 30 seconds
# ########## Evaluation - Episode 6400 ##########
# Timestep: 514611 Average reward is 2.84
# EPISODE 6500 - Eval 99 over 100 - Number of game played 13100 - 11 hours, 7 minutes and 29 secondss
# ########## Evaluation - Episode 6500 ##########
# Timestep: 522661 Average reward is 2.77
# EPISODE 6600 - Eval 99 over 100 - Number of game played 13300 - 11 hours, 27 minutes and 49 seconds
# ########## Evaluation - Episode 6600 ##########
# Timestep: 530681 Average reward is 2.71
# EPISODE 6700 - Eval 99 over 100 - Number of game played 13500 - 11 hours, 48 minutes and 32 seconds
# ########## Evaluation - Episode 6700 ##########
# Timestep: 538690 Average reward is 2.06
# EPISODE 6800 - Eval 99 over 100 - Number of game played 13700 - 12 hours, 9 minutes and 33 seconds
# ########## Evaluation - Episode 6800 ##########
# Timestep: 546739 Average reward is 2.32
# EPISODE 6900 - Eval 99 over 100 - Number of game played 13900 - 12 hours, 30 minutes and 55 seconds
# ########## Evaluation - Episode 6900 ##########
# Timestep: 554769 Average reward is 2.68
# EPISODE 7000 - Eval 99 over 100 - Number of game played 14100 - 12 hours, 52 minutes and 33 seconds
# ########## Evaluation - Episode 7000 ##########
# Timestep: 562806 Average reward is 2.71
# EPISODE 7100 - Eval 99 over 100 - Number of game played 14300 - 13 hours, 14 minutes and 31 seconds
# ########## Evaluation - Episode 7100 ##########
# Timestep: 570835 Average reward is 2.8
# EPISODE 7200 - Eval 99 over 100 - Number of game played 14500 - 13 hours, 36 minutes and 45 seconds
# ########## Evaluation - Episode 7200 ##########
# Timestep: 578876 Average reward is 2.46
# EPISODE 7300 - Eval 99 over 100 - Number of game played 14700 - 13 hours, 59 minutes and 10 seconds
# ########## Evaluation - Episode 7300 ##########
# Timestep: 586912 Average reward is 2.76
# EPISODE 7400 - Eval 99 over 100 - Number of game played 14900 - 14 hours, 22 minutes and 3 secondss
# ########## Evaluation - Episode 7400 ##########
# Timestep: 594928 Average reward is 2.87
# EPISODE 7500 - Eval 99 over 100 - Number of game played 15100 - 14 hours, 45 minutes and 21 seconds
# ########## Evaluation - Episode 7500 ##########
# Timestep: 602970 Average reward is 2.76
# EPISODE 7600 - Eval 99 over 100 - Number of game played 15300 - 15 hours, 8 minutes and 51 secondss
# ########## Evaluation - Episode 7600 ##########
# Timestep: 610985 Average reward is 2.41
# EPISODE 7700 - Eval 99 over 100 - Number of game played 15500 - 15 hours, 32 minutes and 47 seconds
# ########## Evaluation - Episode 7700 ##########
# Timestep: 619016 Average reward is 2.55
# EPISODE 7800 - Eval 99 over 100 - Number of game played 15700 - 15 hours, 57 minutes and 2 secondss
# ########## Evaluation - Episode 7800 ##########
# Timestep: 627063 Average reward is 2.59
# EPISODE 7900 - Eval 99 over 100 - Number of game played 15900 - 16 hours, 21 minutes and 25 seconds
# ########## Evaluation - Episode 7900 ##########
# Timestep: 635086 Average reward is 2.88
# EPISODE 8000 - Eval 99 over 100 - Number of game played 16100 - 16 hours, 46 minutes and 12 seconds
# ########## Evaluation - Episode 8000 ##########
# Timestep: 643111 Average reward is 2.48
# EPISODE 8100 - Eval 99 over 100 - Number of game played 16300 - 17 hours, 11 minutes and 15 seconds
# ########## Evaluation - Episode 8100 ##########
# Timestep: 651170 Average reward is 2.73
# EPISODE 8200 - Eval 99 over 100 - Number of game played 16500 - 17 hours, 36 minutes and 45 seconds
# ########## Evaluation - Episode 8200 ##########
# Timestep: 659217 Average reward is 2.68
# EPISODE 8300 - Eval 99 over 100 - Number of game played 16700 - 18 hours, 2 minutes and 33 secondss
# ########## Evaluation - Episode 8300 ##########
# Timestep: 667247 Average reward is 2.22
# EPISODE 8400 - Eval 99 over 100 - Number of game played 16900 - 18 hours, 28 minutes and 36 seconds
# ########## Evaluation - Episode 8400 ##########
# Timestep: 675282 Average reward is 2.36
# EPISODE 8500 - Eval 99 over 100 - Number of game played 17100 - 18 hours, 55 minutes and 8 secondss
# ########## Evaluation - Episode 8500 ##########
# Timestep: 683316 Average reward is 2.15
# EPISODE 8600 - Eval 99 over 100 - Number of game played 17300 - 19 hours, 22 minutes and 0 secondds
# ########## Evaluation - Episode 8600 ##########
# Timestep: 691372 Average reward is 2.47
# EPISODE 8700 - Eval 99 over 100 - Number of game played 17500 - 19 hours, 49 minutes and 13 seconds
# ########## Evaluation - Episode 8700 ##########
# Timestep: 699416 Average reward is 2.64
# EPISODE 8800 - Eval 99 over 100 - Number of game played 17700 - 20 hours, 16 minutes and 49 seconds
# ########## Evaluation - Episode 8800 ##########
# Timestep: 707461 Average reward is 2.84
# EPISODE 8900 - Eval 99 over 100 - Number of game played 17900 - 20 hours, 44 minutes and 36 seconds
# ########## Evaluation - Episode 8900 ##########
# Timestep: 715482 Average reward is 3.14
# EPISODE 9000 - Eval 99 over 100 - Number of game played 18100 - 21 hours, 12 minutes and 43 seconds
# ########## Evaluation - Episode 9000 ##########
# Timestep: 723499 Average reward is 2.96
# EPISODE 9100 - Eval 99 over 100 - Number of game played 18300 - 21 hours, 41 minutes and 0 secondds
# ########## Evaluation - Episode 9100 ##########
# Timestep: 731535 Average reward is 3.33
# EPISODE 9200 - Eval 99 over 100 - Number of game played 18500 - 22 hours, 9 minutes and 45 secondss
# ########## Evaluation - Episode 9200 ##########
# Timestep: 739562 Average reward is 2.07
# EPISODE 9300 - Eval 99 over 100 - Number of game played 18700 - 22 hours, 38 minutes and 51 seconds
# ########## Evaluation - Episode 9300 ##########
# Timestep: 747580 Average reward is 2.76
# EPISODE 9400 - Eval 99 over 100 - Number of game played 18900 - 23 hours, 8 minutes and 35 secondss
# ########## Evaluation - Episode 9400 ##########
# Timestep: 755586 Average reward is 2.69
# EPISODE 9500 - Eval 99 over 100 - Number of game played 19100 - 23 hours, 38 minutes and 36 seconds
# ########## Evaluation - Episode 9500 ##########
# Timestep: 763613 Average reward is 2.51
# EPISODE 9600 - Eval 99 over 100 - Number of game played 19300 - 1 day, 0 hour and 8 minutes seconds
# ########## Evaluation - Episode 9600 ##########
# Timestep: 771653 Average reward is 2.59
# EPISODE 9700 - Eval 99 over 100 - Number of game played 19500 - 1 day, 0 hour and 39 minutes
# ########## Evaluation - Episode 9700 ##########
# Timestep: 779681 Average reward is 2.27
# EPISODE 9800 - Eval 99 over 100 - Number of game played 19700 - 1 day, 1 hour and 9 minutess
# ########## Evaluation - Episode 9800 ##########
# Timestep: 787709 Average reward is 2.31
# EPISODE 9900 - Eval 99 over 100 - Number of game played 19900 - 1 day, 1 hour and 41 minutes
# ########## Evaluation - Episode 9900 ##########
# Timestep: 795730 Average reward is 2.28
# EPISODE 9999 - Number of game played 19999 - 1 day, 1 hour and 56 minutes
